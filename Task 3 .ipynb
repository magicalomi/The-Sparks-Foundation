# %% [markdown]
# # Importing the necessary packages

# %%
import numpy as npg
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
# %matplotlib inline

# %%
iris=pd.read_csv("C:/Users/omu/Desktop/TSF/Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris=iris.iloc[:,[1,4]].values

# %% [markdown]
# # Creating the Dendogram

# %%
import scipy.cluster.hierarchy as sch
dendrogram=sch.dendrogram(sch.linkage(iris, method='ward'))
plt.title("DENDOGRAM")
plt.xlabel("Flowers")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
from sklearn.cluster import AgglomerativeClustering
hc=AgglomerativeClustering(n_clusters=3,affinity = 'euclidean', linkage='ward')

# %%
clustering=hc.fit_predict(iris)
iris
# Out:
# array([[5.1, 0.2],
#        [4.9, 0.2],
#        [4.7, 0.2],
#        [4.6, 0.2],
#        [5. , 0.2],
#        [5.4, 0.4],
#        [4.6, 0.3],
#        [5. , 0.2],
#        [4.4, 0.2],
#        [4.9, 0.1],
#        [5.4, 0.2],
#        [4.8, 0.2],
#        [4.8, 0.1],
#        [4.3, 0.1],
#        [5.8, 0.2],
#        [5.7, 0.4],
#        [5.4, 0.4],
#        [5.1, 0.3],
#        [5.7, 0.3],
#        [5.1, 0.3],
#        [5.4, 0.2],
#        [5.1, 0.4],
#        [4.6, 0.2],
#        [5.1, 0.5],
#        [4.8, 0.2],
#        [5. , 0.2],
#        [5. , 0.4],
#        [5.2, 0.2],
#        [5.2, 0.2],
#        [4.7, 0.2],
#        [4.8, 0.2],
#        [5.4, 0.4],
#        [5.2, 0.1],
#        [5.5, 0.2],
#        [4.9, 0.1],
#        [5. , 0.2],
#        [5.5, 0.2],
#        [4.9, 0.1],
#        [4.4, 0.2],
#        [5.1, 0.2],
#        [5. , 0.3],
#        [4.5, 0.3],
#        [4.4, 0.2],
#        [5. , 0.6],
#        [5.1, 0.4],
#        [4.8, 0.3],
#        [5.1, 0.2],
#        [4.6, 0.2],
#        [5.3, 0.2],
#        [5. , 0.2],
#        [7. , 1.4],
#        [6.4, 1.5],
#        [6.9, 1.5],
#        [5.5, 1.3],
#        [6.5, 1.5],
#        [5.7, 1.3],
#        [6.3, 1.6],
#        [4.9, 1. ],
#        [6.6, 1.3],
#        [5.2, 1.4],
#        [5. , 1. ],
#        [5.9, 1.5],
#        [6. , 1. ],
#        [6.1, 1.4],
#        [5.6, 1.3],
#        [6.7, 1.4],
#        [5.6, 1.5],
#        [5.8, 1. ],
#        [6.2, 1.5],
#        [5.6, 1.1],
#        [5.9, 1.8],
#        [6.1, 1.3],
#        [6.3, 1.5],
#        [6.1, 1.2],
#        [6.4, 1.3],
#        [6.6, 1.4],
#        [6.8, 1.4],
#        [6.7, 1.7],
#        [6. , 1.5],
#        [5.7, 1. ],
#        [5.5, 1.1],
#        [5.5, 1. ],
#        [5.8, 1.2],
#        [6. , 1.6],
#        [5.4, 1.5],
#        [6. , 1.6],
#        [6.7, 1.5],
#        [6.3, 1.3],
#        [5.6, 1.3],
#        [5.5, 1.3],
#        [5.5, 1.2],
#        [6.1, 1.4],
#        [5.8, 1.2],
#        [5. , 1. ],
#        [5.6, 1.3],
#        [5.7, 1.2],
#        [5.7, 1.3],
#        [6.2, 1.3],
#        [5.1, 1.1],
#        [5.7, 1.3],
#        [6.3, 2.5],
#        [5.8, 1.9],
#        [7.1, 2.1],
#        [6.3, 1.8],
#        [6.5, 2.2],
#        [7.6, 2.1],
#        [4.9, 1.7],
#        [7.3, 1.8],
#        [6.7, 1.8],
#        [7.2, 2.5],
#        [6.5, 2. ],
#        [6.4, 1.9],
#        [6.8, 2.1],
#        [5.7, 2. ],
#        [5.8, 2.4],
#        [6.4, 2.3],
#        [6.5, 1.8],
#        [7.7, 2.2],
#        [7.7, 2.3],
#        [6. , 1.5],
#        [6.9, 2.3],
#        [5.6, 2. ],
#        [7.7, 2. ],
#        [6.3, 1.8],
#        [6.7, 2.1],
#        [7.2, 1.8],
#        [6.2, 1.8],
#        [6.1, 1.8],
#        [6.4, 2.1],
#        [7.2, 1.6],
#        [7.4, 1.9],
#        [7.9, 2. ],
#        [6.4, 2.2],
#        [6.3, 1.5],
#        [6.1, 1.4],
#        [7.7, 2.3],
#        [6.3, 2.4],
#        [6.4, 1.8],
#        [6. , 1.8],
#        [6.9, 2.1],
#        [6.7, 2.4],
#        [6.9, 2.3],
#        [5.8, 1.9],
#        [6.8, 2.3],
#        [6.7, 2.5],
#        [6.7, 2.3],
#        [6.3, 1.9],
#        [6.5, 2. ],
#        [6.2, 2.3],
#        [5.9, 1.8]])

# %%
plt.figure(figsize=(12,8))
plt.scatter(iris[clustering==0,0], iris[clustering==0,1], s=100, c="blue", label='Cluster 1')
plt.scatter(iris[clustering==1,0], iris[clustering==1,1], s=100, c="yellow", label='Cluster 2')
plt.scatter(iris[clustering==2,0], iris[clustering==2,1], s=100, c="red", label='Cluster 3')
plt.title('Clustering of Flowers(Hierarchical Clustering Model)')
plt.grid()
plt.xlabel('Size of the Petals')
plt.ylabel('Size of the Sepals')
plt.show()

# %%
iris_flowers = {
    'Clusters': ['Cluster 1 (BLUE)', 'Cluster 2 (YELLOW)', 'Cluster 3 (RED)'],
    'Flower_Name':['Iris-Certosa', 'Iris-Versicolor','Iris-Verginica']
}
df = pd.DataFrame(iris_flowers, columns=['Clusters','Flower_Name'])
df
# Out:
#              Clusters      Flower_Name
# 0    Cluster 1 (BLUE)     Iris-Certosa
# 1  Cluster 2 (YELLOW)  Iris-Versicolor
# 2     Cluster 3 (RED)   Iris-Verginica

# %% [markdown]
# # K-Means Clustering To Group the Necessary Features

# %%
from sklearn.cluster import KMeans

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
iris['Species']=LE.fit_transform(iris['Species'])
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
x=iris.iloc[:,[0,2]]
y=iris['Species']

# %%
plt.scatter(x.iloc[:,0], x.iloc[:,1], c=y, cmap='gist_rainbow')
plt.xlabel('Sepal Length', fontsize=18)
plt.ylabel('Sepal Width', fontsize=18)
plt.grid()

# %%
km = KMeans(n_clusters = 3, n_jobs = 4, random_state = 21)
km.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=4, precompute_distances='auto',
#        random_state=21, tol=0.0001, verbose=0)

# %%
centers = km.cluster_centers_
print(centers)
# Out:
# [[ 25.           3.42040816]
#  [125.           2.97058824]
#  [ 74.5          2.78      ]]

# %%
#this will tell us to which cluster does the data observations belong.
new_labels = km.labels_
# Plot the identified clusters and compare with the answers
fig, axes = plt.subplots(1, 2, figsize=(18,6))
axes[0].scatter(x.iloc[:, 0], x.iloc[:, 1], c=y, cmap='gist_rainbow',edgecolor='k', s=150)
axes[1].scatter(x.iloc[:, 0], x.iloc[:, 1], c=new_labels, cmap='jet',edgecolor='k', s=150)
axes[0].set_xlabel('Sepal length', fontsize=18)
axes[0].set_ylabel('Sepal width', fontsize=18)
axes[1].set_xlabel('Sepal length', fontsize=18)
axes[1].set_ylabel('Sepal width', fontsize=18)
axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)
axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)
axes[0].set_title('Actual', fontsize=18)
axes[1].set_title('Predicted', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')
